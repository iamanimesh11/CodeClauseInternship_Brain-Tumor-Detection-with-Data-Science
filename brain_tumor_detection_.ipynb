# %%
import os
import keras 
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('dark_background')
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

# %%
encoder = OneHotEncoder()
encoder.fit([[0], [1]]) 

# 0 - Tumor
# 1 - Normal
# Out:
# OneHotEncoder()

# %%
data = []
paths = []
result = []

for r, d, f in os.walk('data/yes'):
    for file in f:
        if '.jpg' in file:
            paths.append(os.path.join(r, file))

for path in paths:
    img = Image.open(path)
    img = img.resize((128,128))
    img = np.array(img)
    if(img.shape == (128,128,3)):
        data.append(np.array(img))
        result.append(encoder.transform([[0]]).toarray())

# %%
paths = []
for r, d, f in os.walk('data/no'):
    for file in f:
        if '.jpg' in file:
            paths.append(os.path.join(r, file))

for path in paths:
    img = Image.open(path)
    img = img.resize((128,128))
    img = np.array(img)
    if(img.shape == (128,128,3)):
        data.append(np.array(img))
        result.append(encoder.transform([[1]]).toarray())

# %%
data = np.array(data)
data.shape
# Out:
# (140, 128, 128, 3)

# %%
result = np.array(result)
result = result.reshape(140,2)

# %%
x_train,x_test,y_train,y_test = train_test_split(data, result, test_size=0.2, shuffle=True, random_state=0)

# %%
model = Sequential()

model.add(Conv2D(32, kernel_size=(2, 2), input_shape=(128, 128, 3), padding = 'Same'))
model.add(Conv2D(32, kernel_size=(2, 2),  activation ='relu', padding = 'Same'))


model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Conv2D(64, kernel_size = (2,2), activation ='relu', padding = 'Same'))
model.add(Conv2D(64, kernel_size = (2,2), activation ='relu', padding = 'Same'))

model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
model.add(Dropout(0.25))

model.add(Flatten())

model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(2, activation='softmax'))

model.compile(loss = "categorical_crossentropy", optimizer='Adamax')
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 128, 32)      416
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 32)      4128
#
#  batch_normalization (Batch  (None, 128, 128, 32)      128
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 64, 64, 32)        0
#  D)
#
#  dropout (Dropout)           (None, 64, 64, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 64)        8256
#
#  conv2d_3 (Conv2D)           (None, 64, 64, 64)        16448
#
#  batch_normalization_1 (Bat  (None, 64, 64, 64)        256
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 32, 32, 64)        0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 32, 32, 64)        0
#
#  flatten (Flatten)           (None, 65536)             0
#
#  dense (Dense)               (None, 512)               33554944
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 33585602 (128.12 MB)
# Trainable params: 33585410 (128.12 MB)
# Non-trainable params: 192 (768.00 Byte)
# _________________________________________________________________
# None

# %%
y_train.shape
# Out:
# (112, 2)

# %%
history = model.fit(x_train, y_train, epochs = 30, batch_size = 40, verbose = 1,validation_data = (x_test, y_test))
# Out:
# Epoch 1/30
# 3/3 [==============================] - 10s 2s/step - loss: 88.0822 - val_loss: 73.9620
# Epoch 2/30
# 3/3 [==============================] - 6s 2s/step - loss: 20.8657 - val_loss: 37.4050
# Epoch 3/30
# 3/3 [==============================] - 6s 2s/step - loss: 12.2630 - val_loss: 15.0422
# Epoch 4/30
# 3/3 [==============================] - 6s 2s/step - loss: 8.1492 - val_loss: 29.5544
# Epoch 5/30
# 3/3 [==============================] - 5s 2s/step - loss: 6.3089 - val_loss: 31.0993
# Epoch 6/30
# 3/3 [==============================] - 6s 2s/step - loss: 3.9555 - val_loss: 19.9098
# Epoch 7/30
# 3/3 [==============================] - 6s 2s/step - loss: 2.0848 - val_loss: 11.1232
# Epoch 8/30
# 3/3 [==============================] - 6s 2s/step - loss: 2.1014 - val_loss: 12.0064
# Epoch 9/30
# 3/3 [==============================] - 6s 2s/step - loss: 1.9500 - val_loss: 16.2962
# Epoch 10/30
# 3/3 [==============================] - 6s 2s/step - loss: 0.8244 - val_loss: 18.6022
# Epoch 11/30
# 3/3 [==============================] - 6s 2s/step - loss: 0.3931 - val_loss: 18.2029
# Epoch 12/30
# 3/3 [==============================] - 6s 2s/step - loss: 0.4611 - val_loss: 16.4672
# Epoch 13/30
# 3/3 [==============================] - 5s 2s/step - loss: 0.3388 - val_loss: 14.0702
# Epoch 14/30
# 3/3 [==============================] - 5s 2s/step - loss: 0.3559 - val_loss: 11.7876
# Epoch 15/30
# 3/3 [==============================] - 6s 2s/step - loss: 0.1178 - val_loss: 9.7527
# Epoch 16/30
# 3/3 [==============================] - 6s 2s/step - loss: 0.0969 - val_loss: 8.0486
# Epoch 17/30
# 3/3 [==============================] - 7s 2s/step - loss: 0.0114 - val_loss: 6.9490
# Epoch 18/30
# 3/3 [==============================] - 6s 2s/step - loss: 0.0874 - val_loss: 6.2325
# Epoch 19/30
# 3/3 [==============================] - 6s 2s/step - loss: 0.0898 - val_loss: 5.9380
# Epoch 20/30
# 3/3 [==============================] - 6s 2s/step - loss: 0.0304 - val_loss: 5.6851
# Epoch 21/30
# 3/3 [==============================] - 6s 2s/step - loss: 0.0052 - val_loss: 5.4227
# Epoch 22/30
# 3/3 [==============================] - 6s 2s/step - loss: 0.0371 - val_loss: 5.1863
# Epoch 23/30
# 3/3 [==============================] - 6s 2s/step - loss: 0.0412 - val_loss: 4.9633
# Epoch 24/30
# 3/3 [==============================] - 6s 2s/step - loss: 0.0448 - val_loss: 4.7743
# Epoch 25/30
# 3/3 [==============================] - 6s 2s/step - loss: 0.0332 - val_loss: 4.6453
# Epoch 26/30
# 3/3 [==============================] - 6s 2s/step - loss: 0.0122 - val_loss: 4.5119
# Epoch 27/30
# 3/3 [==============================] - 6s 2s/step - loss: 0.0532 - val_loss: 4.3971
# Epoch 28/30
# 3/3 [==============================] - 5s 2s/step - loss: 0.0496 - val_loss: 4.2939
# Epoch 29/30
# 3/3 [==============================] - 7s 2s/step - loss: 0.0088 - val_loss: 4.1938
# Epoch 30/30
# 3/3 [==============================] - 6s 2s/step - loss: 0.0081 - val_loss: 4.1085

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Test', 'Validation'], loc='upper right')
plt.show()

# %%
def names(number):
    if number==0:
        return 'Its a Tumor'
    else:
        return 'No, Its not a tumor'

# %%
from matplotlib.pyplot import imshow
img = Image.open('data/yes/WhiteMatterHyperintensities-1200x630-cropped.jpg')
x = np.array(img.resize((128,128)))
x = x.reshape(1,128,128,3)
res = model.predict_on_batch(x)
classification = np.where(res == np.amax(res))[1][0]
imshow(img)
print(str(res[0][classification]*100) + '% Confidence This Is ' + names(classification))
# Out:
# 100.0% Confidence This Is Its a Tumor

# %%
# Save the Keras model to a file
model.save('brain_tumor_detection_model.h5')
# Out:
# C:\Users\Animesh\anaconda3\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
